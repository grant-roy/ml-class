# %% [markdown]
# ## Calculating probability of adoption, given some inputs
#
# Given the attached pdf, the goal is to implement the calculations for the first example.  This data represents customer adoption rates of a service based on 3 predictors.  As stated, logistic regression is powerful tool that is very often used when modelling consumer utility choices.
#
# Our data is categorical, and we are interested in predicting some binary outcome.  In this case that outcome is whether or not a user will adopt a service.
#
# Our predictors are:
#
# * x1  : 0 if no college, 1 if some college or above.
# * x2  : 0 if no change in residence in previous 5 years, 1 otherwise
# * x3  : 0 if income is low, 1 if income is high

# %%
from __future__ import division
import logistic_regression as lg
import create_dataset as cd
import math

# create our dataset 
cd.create_dataset()

# we can calculate different probabilites based on
# sub samples of the population 
print lg.calculate_probs(x1=0,x2=0,x3=0)


print lg.calculate_probs(x1=0,x2=1,x3=0)


print lg.calculate_probs(x1=0,x2=0,x3=1)
# Out:
# 0.0758581800212
# 0.181235382206
# 0.113447517156

# %% [markdown]
# As we can see above, the calcuated values match those shown in the PDF.
