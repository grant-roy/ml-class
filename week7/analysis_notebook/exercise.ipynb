# %% [markdown]
# ## 1 Create formula and iteratively converge on N
#
# > Given the following formula, write a python function, then iteratively feed N into it, until N converges. Use $\delta=.1, \epsilon=.1, d_{vc}=50$
#
# $$ N \ge   \frac{8}{ \epsilon ^ 2} ln \frac{4mH(2N)}{\delta} $$
#
#
# ## 2  Create Python function from formula for Hoeffding bound
#
# > Convert the following formula into a Python function, where the function parameters are the variables in the formula
#
# $$ \sqrt{ \frac{1}{2N} ln \frac{2M}{\delta} }  $$
#
# ## 3 Estimate E_out using a test set and the Hoeffding Inequality
#
# > Use the room sensor data set to again train the perceptron, this time use the performance on the test set along with the hoeffding bound to estimate E_out
#
# $$ E_{out} \le E_{test} + \sqrt{ \frac{1}{2N} ln \frac{2M}{\delta} } $$
#
# ## 4 Calculating additional generalization bounds, problem 2.20
#
# > Using python, create functions that will calculate the following generalization bounds
#
#
#
# > **Rademacher Penalty Bound**
#
# $$ \epsilon \le \sqrt{ \frac{2ln(2Nm_{h}(N))}{N} } + \sqrt{ \frac{2}{N} ln \frac{1}{\delta} } + \frac{1}{N}  $$
#
# > **Parrondo and Van den Broek**
#
# $$ \epsilon \le \sqrt{ \frac{1}{N} \left( 2\epsilon + ln \frac{6m_h(2N)}{\delta}  \right) }  $$
#
# > **Devroye**
#
# $$ \epsilon \le \sqrt{ \frac{1}{2N} \left( 4\epsilon(1 + \epsilon) + ln \frac{4m_h(N^2)}{\delta} \right) } $$
