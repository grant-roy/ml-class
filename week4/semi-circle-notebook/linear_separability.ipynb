# %%
import semi_circles as sc
import perceptron as pt
import regression as rg
import scatter_plot as sp

# %% [markdown]
# ### Semi Circle fit via Regression Line
#
# A regression line is not appropriate for data that we wish to linearly separate or *classify* into distinct subgroups. We can see that below where we create two separate semi circular regions in the plane, followed by plotting a linear regression line fit to the data.

# %%
data  = samples[['x','y']]
m,c  = rg.regression(data)

rg.plot_regression(data, m, c)

# %% [markdown]
# ### Semi Circle Separation via Perceptron Algorithm
#
# If we wish to separate the data, the perceptron algorithm is an appropriate choice.

# %%
samples  = sc.semi_circular_samples(offset=7.5,sep=5)
w = pt.perceptron(samples)
sp.scatter(samples, w)
